# %%
from src.run_demo import run_demo
run_demo()

# %%
import json
print('Sample alerts (first 3):')
with open('outputs/sample_alerts.json') as f:
    for i, line in enumerate(f):
        if i>=3: break
        print(json.loads(line))
